# %%
#importing libraries for visiualizing and understanding dataset
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
hap_df=pd.read_csv('Happiness_score.csv')

# %% [markdown]
# # Finding insights of the data and what it consist of

# %%
hap_df.head(20)
# Out:
#                  Country                           Region  Happiness Rank  \
# 0            Switzerland                   Western Europe               1
# 1                Iceland                   Western Europe               2
# 2                Denmark                   Western Europe               3
# 3                 Norway                   Western Europe               4
# 4                 Canada                    North America               5
# 5                Finland                   Western Europe               6
# 6            Netherlands                   Western Europe               7
# 7                 Sweden                   Western Europe               8
# 8            New Zealand        Australia and New Zealand               9
# 9              Australia        Australia and New Zealand              10
# 10                Israel  Middle East and Northern Africa              11
# 11            Costa Rica      Latin America and Caribbean              12
# ...

# %%
hap_df.tail(20)
# Out:
#                       Country                           Region  \
# 138       Congo (Brazzaville)               Sub-Saharan Africa
# 139                   Comoros               Sub-Saharan Africa
# 140                    Uganda               Sub-Saharan Africa
# 141                   Senegal               Sub-Saharan Africa
# 142                     Gabon               Sub-Saharan Africa
# 143                     Niger               Sub-Saharan Africa
# 144                  Cambodia                Southeastern Asia
# 145                  Tanzania               Sub-Saharan Africa
# 146                Madagascar               Sub-Saharan Africa
# 147  Central African Republic               Sub-Saharan Africa
# 148                      Chad               Sub-Saharan Africa
# 149                    Guinea               Sub-Saharan Africa
# 150               Ivory Coast               Sub-Saharan Africa
# 151              Burkina Faso               Sub-Saharan Africa
# ...

# %%
hap_df.shape #finding the number of rows of columns
# Out:
# (158, 12)

# %%
hap_df.info() #finding the information abou the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#finding what are the different regions of the world from where the result is been taken
print(hap_df['Region'].unique())
#finddig the number of sample taken from a particular region
print(hap_df['Region'].value_counts())
# Out:
# ['Western Europe' 'North America' 'Australia and New Zealand'
#  'Middle East and Northern Africa' 'Latin America and Caribbean'
#  'Southeastern Asia' 'Central and Eastern Europe' 'Eastern Asia'
#  'Sub-Saharan Africa' 'Southern Asia']
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
#finding which countries took part across the world
print(hap_df['Country'].unique())
# Out:
# ['Switzerland' 'Iceland' 'Denmark' 'Norway' 'Canada' 'Finland'
#  'Netherlands' 'Sweden' 'New Zealand' 'Australia' 'Israel' 'Costa Rica'
#  'Austria' 'Mexico' 'United States' 'Brazil' 'Luxembourg' 'Ireland'
#  'Belgium' 'United Arab Emirates' 'United Kingdom' 'Oman' 'Venezuela'
#  'Singapore' 'Panama' 'Germany' 'Chile' 'Qatar' 'France' 'Argentina'
#  'Czech Republic' 'Uruguay' 'Colombia' 'Thailand' 'Saudi Arabia' 'Spain'
#  'Malta' 'Taiwan' 'Kuwait' 'Suriname' 'Trinidad and Tobago' 'El Salvador'
#  'Guatemala' 'Uzbekistan' 'Slovakia' 'Japan' 'South Korea' 'Ecuador'
#  'Bahrain' 'Italy' 'Bolivia' 'Moldova' 'Paraguay' 'Kazakhstan' 'Slovenia'
#  'Lithuania' 'Nicaragua' 'Peru' 'Belarus' 'Poland' 'Malaysia' 'Croatia'
#  'Libya' 'Russia' 'Jamaica' 'North Cyprus' 'Cyprus' 'Algeria' 'Kosovo'
#  'Turkmenistan' 'Mauritius' 'Hong Kong' 'Estonia' 'Indonesia' 'Vietnam'
#  'Turkey' 'Kyrgyzstan' 'Nigeria' 'Bhutan' 'Azerbaijan' 'Pakistan' 'Jordan'
# ...

# %%
#checking the null values in the datasets
sns.heatmap(hap_df.isnull())

# %%
hap_df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#the dataset do not contain any nan values

# %%
#using label Encoder for changing the region column values from object to numeric
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
lb.fit(hap_df['Region'])
lb.classes_
# Out:
# array(['Australia and New Zealand', 'Central and Eastern Europe',
#        'Eastern Asia', 'Latin America and Caribbean',
#        'Middle East and Northern Africa', 'North America',
#        'Southeastern Asia', 'Southern Asia', 'Sub-Saharan Africa',
#        'Western Europe'], dtype=object)

# %%
hap_df['Region']=lb.fit_transform(hap_df['Region'])

# %%
hap_df['Region'].unique()
# Out:
# array([9, 5, 0, 4, 3, 6, 1, 2, 8, 7])

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lineplot(x=hap_df['Happiness Score'],y= hap_df['Standard Error'])

# %%
sns.lineplot(x=hap_df['Happiness Score'],y= hap_df['Economy (GDP per Capita)'])

# %%
sns.lineplot(x=hap_df['Happiness Score'],y= hap_df['Family'])

# %%
sns.lineplot(x=hap_df['Happiness Score'],y=hap_df['Health (Life Expectancy)'])

# %%
sns.lineplot(x=hap_df['Happiness Score'],y=hap_df['Freedom'])

# %%
sns.lineplot(x=hap_df['Happiness Score'],y=hap_df['Trust (Government Corruption)'])

# %%
sns.lineplot(hap_df['Region'], hap_df['Happiness Score'])

# %%
sns.scatterplot(hap_df['Happiness Score'], hap_df['Trust (Government Corruption)'])

# %%
sns.pairplot(hap_df)

# %% [raw]
# #how the regions are named after label encoding
# 0- western Europe
# 1- North America
# 2- Australia and NewZeland
# 3- Middle East and Nothern Africa
# 4- Latin America
# 5- Southeastern Asia
# 6- Central and Eastern Europe
# 7- Eastern Asia
# 8- Sub- Saharan Africa
# 9-Southern Asia

# %%
#Box Plot of Happiness Score by Each Region
sns.boxplot(hap_df['Region'], hap_df['Happiness Score'])

# %% [markdown]
# Middle East & Northern Africa have largest IQR & Range

# %% [markdown]
# # Univariate Analysis

# %%
collist=hap_df.columns.values
ncol=12
nrows=10
plt.figure(figsize=(30,45))
for i in range (1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(hap_df[collist[i]],color='orange',orient='v')

# %%
#outliers are present in some columns of the datasets

# %%
hap_df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
sns.distplot(hap_df['Region'])

# %%
sns.distplot(hap_df['Happiness Score'])

# %%
sns.distplot(hap_df['Standard Error'])

# %%
sns.distplot(hap_df['Economy (GDP per Capita)'])

# %%
sns.distplot(hap_df['Family'])

# %%
sns.distplot(hap_df['Freedom'])

# %%
sns.distplot(hap_df['Trust (Government Corruption)'])

# %%
sns.distplot(hap_df['Dystopia Residual'])

# %%
sns.distplot(hap_df['Generosity'])

# %% [markdown]
# # STATISTICAL ANALYSIS

# %%
hap_df.describe()
# Out:
#            Region  Happiness Rank  Happiness Score  Standard Error  \
# count  158.000000      158.000000       158.000000      158.000000
# mean     5.120253       79.493671         5.375734        0.047885
# std      2.993321       45.754363         1.145010        0.017146
# min      0.000000        1.000000         2.839000        0.018480
# 25%      3.000000       40.250000         4.526000        0.037268
# 50%      4.500000       79.500000         5.232500        0.043940
# 75%      8.000000      118.750000         6.243750        0.052300
# max      9.000000      158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# ...

# %%
happiness_cor=hap_df.corr()

# %%
happiness_cor
# Out:
#                                  Region  Happiness Rank  Happiness Score  \
# Region                         1.000000        0.213773        -0.176791
# Happiness Rank                 0.213773        1.000000        -0.992105
# Happiness Score               -0.176791       -0.992105         1.000000
# Standard Error                -0.022600        0.158516        -0.177254
# Economy (GDP per Capita)      -0.260139       -0.785267         0.780966
# Family                        -0.168533       -0.733644         0.740605
# Health (Life Expectancy)      -0.357508       -0.735613         0.724200
# Freedom                        0.092567       -0.556886         0.568211
# Trust (Government Corruption)  0.165040       -0.372315         0.395199
# Generosity                     0.273557       -0.160142         0.180319
# Dystopia Residual             -0.057276       -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(happiness_cor,annot=True)

# %%
#Checking the skewness

# %%
hap_df.skew()
# Out:
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
#there is some skewness in 'standard Error','Famliy','Health','Trust(goverment corruption)','Generosity', columns respectively

# %%
#dropping the country column as it is not much contributing to the happiness score
hap_df.drop('Country',axis=1,inplace=True)

# %%
hap_df.head()
# Out:
#    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0       9               1            7.587         0.03411
# 1       9               2            7.561         0.04884
# 2       9               3            7.527         0.03328
# 3       9               4            7.522         0.03880
# 4       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
#hence the country column is successfully dropped

# %% [markdown]
# # Removing Outliers and skewness from the dataset

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(hap_df))

# %%
print(z)
# Out:
# [[1.30025593 1.72099989 1.93736005 ... 2.30965159 0.47103971 0.75825809]
#  [1.30025593 1.69907456 1.91458063 ... 0.01647953 1.57585637 1.09285682]
#  [1.30025593 1.67714922 1.88479215 ... 2.8427738  0.8242928  0.71233526]
#  ...
#  [0.37544095 1.67742676 2.0761992  ... 0.38141902 1.85689094 3.20843049]
#  [0.96511655 1.69935209 2.1646885  ... 0.35771452 0.31694987 0.48198451]
#  [0.96511655 1.72127743 2.22251319 ... 0.30180313 0.5581534  0.96361241]]

# %%
threshold=3

# %%
print(np.where(z>3)) #printing all the value position which are greater than the threshold value
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  3,  3,  3,  9,  5,  8, 10,  5], dtype=int64))

# %%
z[27][8]#checking wether the result is correct or not
# Out:
# 3.1646194851713774

# %%
happ=hap_df[(z<3).all(axis=1)] #removing the outliers

# %%
happ.head()
# Out:
#    Region  Happiness Rank  Happiness Score  Standard Error  \
# 0       9               1            7.587         0.03411
# 1       9               2            7.561         0.04884
# 2       9               3            7.527         0.03328
# 3       9               4            7.522         0.03880
# 4       5               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
# 1                   1.30232  1.40223                   0.94784  0.62877
# 2                   1.32548  1.36058                   0.87464  0.64938
# 3                   1.45900  1.33095                   0.88521  0.66973
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.41978     0.29678            2.51738
# ...

# %%
print(happ.shape, hap_df.shape)
# Out:
# (149, 11) (158, 11)

# %%
#we are left with 149 rows after removing the outliers 
#hence there is a difference of only 9 rows in the new dataset and the old datasets so taking the old dataset for model evaluation

# %%
#checkig the skewness after removing the outliers
happ.skew()
# Out:
# Region                          -0.096985
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %%
#removing skewness
colllist=hap_df.columns.values
for i in range(0,len(colllist)):
    if hap_df.skew().loc[colllist[i]]>0.55:
        hap_df[colllist[i]]=np.sqrt(hap_df[colllist[i]])

# %%
#recheking the skewness
hap_df.skew()
# Out:
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.225889
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Splitting The data into training and testing sets

# %%
y=hap_df['Happiness Score']

# %%
hap_df.drop('Happiness Score',axis=1,inplace=True)

# %%
x=hap_df.iloc[:,:]

# %%
x.head()
# Out:
#    Region  Happiness Rank  Standard Error  Economy (GDP per Capita)   Family  \
# 0       9               1        0.184689                   1.39651  1.34951
# 1       9               2        0.220998                   1.30232  1.40223
# 2       9               3        0.182428                   1.32548  1.36058
# 3       9               4        0.196977                   1.45900  1.33095
# 4       5               5        0.188494                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                       0.647904
# 1                   0.94784  0.62877                       0.376098
# 2                   0.87464  0.64938                       0.695392
# 3                   0.88521  0.66973                       0.604177
# 4                   0.90563  0.63297                       0.574082
#
#    Generosity  Dystopia Residual
# 0    0.544775            2.51738
# ...

# %%
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %%
#Scaling the data in x
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
df_x=sc.fit_transform(x)

# %%
x=df_x
print(x)
# Out:
# [[ 1.30025593 -1.72099989 -0.875515   ...  1.99453385  0.57205491
#    0.75825809]
#  [ 1.30025593 -1.69907456  0.14292893 ...  0.19008801  1.44080569
#    1.09285682]
#  [ 1.30025593 -1.67714922 -0.93893098 ...  2.30979156  0.86858624
#    0.71233526]
#  ...
#  [-0.37544095  1.67742676  0.22551281 ...  0.57986048  1.63848687
#   -3.20843049]
#  [ 0.96511655  1.69935209  2.19747225 ... -0.20087891 -0.18313939
#   -0.48198451]
#  [ 0.96511655  1.72127743  1.21910044 ... -0.13199882 -0.45127425
#   -0.96361241]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import train_test_split

# %%
#Finding the best Random state

max_score=0
final_rstate=0

for i in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=i)
    lm=LinearRegression() 
    lm.fit(x_train,y_train)
    lm.score(x_train,y_train)
    pred=lm.predict(x_test)
    r_score=r2_score(y_test,pred)
    print("R2 SCORE is equal to :",r_score,"at random state",i)
    
    if r_score > max_score:
        max_score=r_score
        final_rstate=i
        
        
    
    
print("The maximum r2_score is ",max_score, "at random state",final_rstate)
# Out:
# R2 SCORE is equal to : 0.9983697466028693 at random state 42
# R2 SCORE is equal to : 0.9980435222783127 at random state 43
# R2 SCORE is equal to : 0.9988891925024563 at random state 44
# R2 SCORE is equal to : 0.9988990824842444 at random state 45
# R2 SCORE is equal to : 0.9982434701512236 at random state 46
# R2 SCORE is equal to : 0.9983905404915476 at random state 47
# R2 SCORE is equal to : 0.99865861746289 at random state 48
# R2 SCORE is equal to : 0.9968711241535042 at random state 49
# R2 SCORE is equal to : 0.9982877171625424 at random state 50
# R2 SCORE is equal to : 0.9978630783506172 at random state 51
# R2 SCORE is equal to : 0.9986288320684518 at random state 52
# R2 SCORE is equal to : 0.9984026347126276 at random state 53
# R2 SCORE is equal to : 0.9982817236715744 at random state 54
# R2 SCORE is equal to : 0.9980187663762087 at random state 55
# R2 SCORE is equal to : 0.9979168973465552 at random state 56
# ...

# %%
#finalizing the train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=65)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (118, 10) (40, 10) (118,) (40,)

# %%
lm.coef_
# Out:
# array([ 0.00385925, -0.0579908 , -0.00109811,  0.38455096,  0.26224326,
#         0.24752212,  0.1402923 ,  0.11151079,  0.10832078,  0.5172204 ])

# %%
lm.intercept_
# Out:
# 5.375790257839092

# %%
print("ERRORS")


print("MEan Absolute error:",mean_absolute_error(y_test,pred))
print("Mean squared error:",mean_absolute_error(y_test,pred))

print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# ERRORS
# MEan Absolute error: 1.2895677601927036
# Mean squared error: 1.2895677601927036
# Root mean squared error: 1.681280974780508

# %%
#applying regularization techniques to overcome underfit and overfit

# %%
from sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso(alpha=0.01)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.996340650644566

# %%
ls.coef_
# Out:
# array([ 0.00668778, -0.49006384, -0.00082514,  0.22453115,  0.16582714,
#         0.13243023,  0.07742507,  0.07121693,  0.06866525,  0.30626594])

# %%
rd=Ridge(alpha=0.01)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9984926247258732

# %%
rd.coef_
# Out:
# array([ 0.00278893, -0.07566676, -0.0039579 ,  0.38492052,  0.25449061,
#         0.23530132,  0.13720913,  0.10406398,  0.11520047,  0.50864022])

# %%
from sklearn.linear_model import ElasticNet
enr=ElasticNet(alpha=0.01)
enr=ElasticNet()
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print(enr.score(x_train,y_train))
enr.coef_
# Out:
# 0.6192550801677579
# array([-0.        , -0.38598947, -0.        ,  0.05928433,  0.        ,
#         0.01162932,  0.        ,  0.        ,  0.        ,  0.        ])

# %%
#as there is huge difference between elastic net score and Linear regression score therefore finalizing Elasticnet model

# %%
from sklearn.externals import joblib
joblib.dump(enr,"enr_happiness_predict.pkl")
# Out:
# ['enr_happiness_predict.pkl']
